# %%
# !pip -q install yfinance statsmodels plotly

# %%
import numpy as np
import pandas as pd
import yfinance as yf
import statsmodels.api as sm
import plotly.express as px

# %%
START = "2018-01-01"
END = None              # None = today
FREQ = "W"              # "D" daily or "W" weekly (weekly often cleaner for TE)

# Choose ONE benchmark (index or ETF proxy). Examples: "SPY", "^GSPC", "QQQ", "ACWI"
BENCHMARK_TICKER = "^NSEI"

# ETFs you want to evaluate (friendly_name: ticker)
ETF_TICKERS = {
    "iShares MSCI": "INDA",
    "Frnklin FTSE": "FLIN",
    "WisdomTree India Earnings Fund": "EPI",
    "iShares MSCI India Small-Cap": "SMIN",
    "iShares India 50 ETF": "INDY",
    "Columbia Consumer ETF": "INCO",
    "Invesco India ETF": "PIN",
    "The India Internet": "INQQ",
    "VanEck India Growth Leaders": "GLIN",
    "Daily MSCI India": "INDL",
    # add more:
    # "India": "INDA",
    # "EM": "EEM",
}

# %%
def download_ohlcv(tickers, start, end):
    raw = yf.download(tickers, start=start, end=end, progress=False, auto_adjust=False)
    # expected MultiIndex columns for multiple tickers
    return raw

def resample_prices(px: pd.DataFrame, freq: str):
    if freq.upper().startswith("W"):
        return px.resample("W-FRI").last()
    return px

def safe_prices(series: pd.Series) -> pd.Series:
    # Fix bad ticks: non-positive -> NaN -> ffill
    s = series.copy()
    s = s.mask(s <= 0, np.nan).ffill()
    return s.dropna()

def returns_simple(px: pd.Series, freq: str) -> pd.Series:
    px = safe_prices(px)
    px = resample_prices(px.to_frame("p"), freq)["p"]
    return px.pct_change().dropna()

def annual_factor(freq: str) -> float:
    return 52.0 if freq.upper().startswith("W") else 252.0

def tracking_metrics(etf_ret: pd.Series, bmk_ret: pd.Series, freq: str):
    df = pd.DataFrame({"etf": etf_ret, "bmk": bmk_ret}).dropna()
    df["active"] = df["etf"] - df["bmk"]

    ann = annual_factor(freq)
    te = df["active"].std() * np.sqrt(ann)                    # Tracking Error (annualized)
    td = df["active"].mean() * ann                            # Tracking Difference (annualized mean active return)
    ir = (df["active"].mean() / df["active"].std()) * np.sqrt(ann) if df["active"].std() > 0 else np.nan

    # Regression-based beta/alpha vs benchmark (not CAPM, just benchmark regression)
    X = sm.add_constant(df["bmk"])
    fit = sm.OLS(df["etf"], X).fit()
    alpha_ann = fit.params["const"] * ann
    beta = fit.params["bmk"]
    r2 = fit.rsquared

    return {
        "TrackingError_ann": float(te),
        "TrackingDiff_ann": float(td),
        "InfoRatio": float(ir),
        "Alpha_vs_Bmk_ann": float(alpha_ann),
        "Beta_vs_Bmk": float(beta),
        "R2_vs_Bmk": float(r2),
        "Obs": int(len(df))
    }

def liquidity_metrics(adj_close: pd.Series, volume: pd.Series, freq: str):
    # Use daily data for liquidity by default (even if returns are weekly)
    px = safe_prices(adj_close)
    vol = volume.reindex(px.index).replace(0, np.nan)

    dollar_vol = (px * vol).dropna()

    # Simple liquidity proxies
    avg_vol = float(vol.dropna().mean())
    avg_dollar_vol = float(dollar_vol.mean())
    med_dollar_vol = float(dollar_vol.median())

    # % of days with "missing/zero" volume (a red flag for liquidity)
    pct_missing_vol = float((volume.reindex(px.index).fillna(0) <= 0).mean())

    # Amihud illiquidity proxy: |return| / dollar volume  (lower is more liquid)
    ret_d = px.pct_change().dropna()
    dv_align = dollar_vol.reindex(ret_d.index).dropna()
    ret_align = ret_d.reindex(dv_align.index)
    amihud = float((ret_align.abs() / dv_align).replace([np.inf, -np.inf], np.nan).dropna().mean())

    return {
        "AvgVolume_shares": avg_vol,
        "AvgDollarVolume": avg_dollar_vol,
        "MedianDollarVolume": med_dollar_vol,
        "PctDays_ZeroOrMissingVolume": pct_missing_vol,
        "Amihud_Illiquidity": amihud,
    }

def explain_tracking_row(name, m):
    te = m["TrackingError_ann"]
    td = m["TrackingDiff_ann"]
    ir = m["InfoRatio"]
    beta = m["Beta_vs_Bmk"]
    r2 = m["R2_vs_Bmk"]
    alpha = m["Alpha_vs_Bmk_ann"]

    return f"""
[{name}] Tracking vs {BENCHMARK_TICKER}
- Tracking Error (annualized): {te:.2%}
  Meaning: typical yearly size of deviations from the benchmark. Lower = tracks closer.
  Numbers: Under 0.5% is Excellent, 0.5-1.5% is Good/Acceptable and anything above 2% is very high and indicates significant performance deviation from the index.
- Tracking Difference (annualized): {td:.2%}
  Meaning: average annual over/underperformance vs benchmark. Positive = beat benchmark on average.
- Information Ratio (IR): {ir:.2f}
  Meaning: active return per unit of tracking error. Higher is better (if stable).
- Beta vs benchmark: {beta:.2f}, R²: {r2:.2f}
  Meaning: beta shows sensitivity to benchmark; R² shows how much ETF moves are explained by benchmark.
- Alpha vs benchmark (annualized intercept): {alpha:.2%}
  Meaning: average return not explained by benchmark exposure (not “true” CAPM alpha—benchmark-based).
"""

def explain_liquidity_row(name, l):
    adv = l["AvgDollarVolume"]
    amihud = l["Amihud_Illiquidity"]
    pct0 = l["PctDays_ZeroOrMissingVolume"]

    return f"""
[{name}] Liquidity proxies
- Average Dollar Volume (ADV): ${adv:,.0f} per day
  Meaning: bigger ADV usually = easier to trade with less price impact.
- Amihud Illiquidity: {amihud:.2e}
  Meaning: |return| per $ traded. Lower = more liquid (less price move per unit volume).
- % Days zero/missing volume: {pct0:.2%}
  Meaning: should be ~0% for liquid ETFs; higher can indicate stale/poor data or illiquidity.
"""

# %%
tickers_all = list(set(list(ETF_TICKERS.values()) + [BENCHMARK_TICKER]))
raw = download_ohlcv(tickers_all, START, END)

# Grab Adj Close and Volume in a ticker-safe way
adj = raw["Adj Close"] if isinstance(raw.columns, pd.MultiIndex) else raw[["Adj Close"]]
vol = raw["Volume"] if isinstance(raw.columns, pd.MultiIndex) else raw[["Volume"]]

# Benchmark returns (for tracking)
bmk_px = adj[BENCHMARK_TICKER] if BENCHMARK_TICKER in adj.columns else adj.iloc[:, 0]
bmk_ret = returns_simple(bmk_px, FREQ)

# %%
tracking_rows = []
liquidity_rows = []
explanations = []

for name, tkr in ETF_TICKERS.items():
    if tkr not in adj.columns:
        print(f"Skipping {name} ({tkr}): no data returned.")
        continue

    etf_ret = returns_simple(adj[tkr], FREQ)

    # Check if etf_ret is empty before proceeding with tracking calculations
    if etf_ret.empty or bmk_ret.empty:
        print(f"Skipping {name} ({tkr}): no valid return data for tracking metrics (either ETF or benchmark returns are empty).")
        t_metrics = {
            "TrackingError_ann": np.nan,
            "TrackingDiff_ann": np.nan,
            "InfoRatio": np.nan,
            "Alpha_vs_Bmk_ann": np.nan,
            "Beta_vs_Bmk": np.nan,
            "R2_vs_Bmk": np.nan,
            "Obs": 0
        }
        tracking_rows.append({"ETF": name, "Ticker": tkr, **t_metrics})
        explanations.append(f"\n[{name}] No valid return data for tracking metrics (either ETF or benchmark returns are empty).")
    else:
        # tracking
        t_metrics = tracking_metrics(etf_ret, bmk_ret, FREQ)
        tracking_rows.append({"ETF": name, "Ticker": tkr, **t_metrics})
        explanations.append(explain_tracking_row(name, t_metrics))

    # liquidity (daily-based) - we can still try to get liquidity metrics
    # even if returns were empty, as liquidity uses daily prices and volumes.
    # However, if adj[tkr] is completely empty/NaN, safe_prices will return an empty series,
    # which liquidity_metrics should handle gracefully by returning NaNs.
    l_metrics = liquidity_metrics(adj[tkr], vol[tkr] if tkr in vol.columns else pd.Series(dtype=float), FREQ)
    liquidity_rows.append({"ETF": name, "Ticker": tkr, **l_metrics})
    explanations.append(explain_liquidity_row(name, l_metrics))

tracking_table = pd.DataFrame(tracking_rows).sort_values("TrackingError_ann")
liquidity_table = pd.DataFrame(liquidity_rows).sort_values("AvgDollarVolume", ascending=False)

tracking_table
# Out:
#                               ETF Ticker  TrackingError_ann  TrackingDiff_ann  \
# 4            iShares India 50 ETF   INDY           0.084448         -0.050222
# 1                    Frnklin FTSE   FLIN           0.088128         -0.040680
# 6               Invesco India ETF    PIN           0.090620         -0.043287
# 0                    iShares MSCI   INDA           0.091456         -0.049014
# 2  WisdomTree India Earnings Fund    EPI           0.095263         -0.032482
# 5           Columbia Consumer ETF   INCO           0.121855         -0.047536
# 3    iShares MSCI India Small-Cap   SMIN           0.138604         -0.054806
# 7              The India Internet   INQQ           0.140262         -0.102980
# 8     VanEck India Growth Leaders   GLIN           0.148386         -0.140643
# 9                Daily MSCI India   INDL           0.365252         -0.065247
#
#    InfoRatio  Alpha_vs_Bmk_ann  Beta_vs_Bmk  R2_vs_Bmk  Obs
# 4  -0.594708         -0.052155     1.015687   0.788835  419
# 1  -0.461600         -0.037700     0.976314   0.760360  414
# 6  -0.477677         -0.038767     0.963327   0.745417  419
# 0  -0.535931         -0.050144     1.009169   0.758587  419
# 2  -0.340973         -0.036532     1.032860   0.752617  419
# 5  -0.390106         -0.040052     0.939277   0.606741  419
# 3  -0.395411         -0.057515     1.021979   0.583957  419
# 7  -0.734195         -0.122614     1.187996   0.526383  197
# 8  -0.947822         -0.150939     1.083536   0.581078  419
# 9  -0.178634         -0.266034     2.629084   0.733072  419

# %%
liquidity_table
# Out:
#                               ETF Ticker  AvgVolume_shares  AvgDollarVolume  \
# 0                    iShares MSCI   INDA      4.333070e+06     1.765037e+08
# 2  WisdomTree India Earnings Fund    EPI      1.067965e+06     3.148404e+07
# 3    iShares MSCI India Small-Cap   SMIN      1.061627e+05     6.112630e+06
# 4            iShares India 50 ETF   INDY      1.203253e+05     4.213373e+06
# 1                    Frnklin FTSE   FLIN      1.149753e+05     4.213326e+06
# 9                Daily MSCI India   INDL      5.636057e+04     2.423966e+06
# 5           Columbia Consumer ETF   INCO      2.083250e+04     1.109812e+06
# 8     VanEck India Growth Leaders   GLIN      2.437852e+04     9.656114e+05
# 6               Invesco India ETF    PIN      4.667367e+04     8.174128e+05
# 7              The India Internet   INQQ      1.833492e+04     2.628500e+05
#
#    MedianDollarVolume  PctDays_ZeroOrMissingVolume  Amihud_Illiquidity
# 0        1.478119e+08                     0.029313        5.864656e-11
# 2        2.648364e+07                     0.029313        3.867458e-10
# 3        2.717965e+06                     0.029313        5.949246e-09
# 4        2.715919e+06                     0.029313        4.003348e-09
# 1        2.357465e+05                     0.039435        1.766368e-07
# 9        1.700569e+06                     0.029313        1.223644e-08
# 5        4.045664e+05                     0.029313        4.084931e-08
# 8        4.930710e+05                     0.029313        4.404732e-08
# 6        5.276103e+05                     0.029313        2.450196e-08
# 7        1.573612e+05                     0.036735        8.537772e-07

# %%
fig1 = px.bar(tracking_table, x="ETF", y="TrackingError_ann", title=f"Tracking Error (annualized) vs {BENCHMARK_TICKER}")
fig1.update_layout(height=450)
fig1.show()

# Liquidity: Avg Dollar Volume bar
fig2 = px.bar(liquidity_table, x="ETF", y="AvgDollarVolume", title="Average Dollar Volume (ADV)")
fig2.update_layout(height=450)
fig2.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="8e1e4d0a-aa84-4028-a520-dfa441fb0fd4" class="plotly-graph-div" style="height:450px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8e1e4d0a-aa84-4028-a520-dfa441fb0fd4")) {                    Plotly.newPlot(                        "8e1e4d0a-aa84-4028-a520-dfa441fb0fd4",                        [{"alignmentgroup":"True","hovertemplate":"ETF=%{x}\u003cbr\u003eTrackingError_ann=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["iShares India 50 ETF","Frnklin FTSE","Invesco India ETF","iShares MSCI","WisdomTree India Earnings Fund","Columbia Consumer ETF","iShares MSCI India Small-Cap","The India Internet","VanEck India Growth Leaders","Daily MSCI India"],"xaxis":"x","y":[0.08444753243412595,0.08812830994155557,0.09062016529381227,0.09145644714712034,0.09526263769649833,0.1218549118672297,0.1386044024116004,0.14026231066909553,0.1483856430955692,0.3652523376385524],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0 ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="1a5d77af-a2a9-4d6e-9e9d-a085ae98ed66" class="plotly-graph-div" style="height:450px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1a5d77af-a2a9-4d6e-9e9d-a085ae98ed66")) {                    Plotly.newPlot(                        "1a5d77af-a2a9-4d6e-9e9d-a085ae98ed66",                        [{"alignmentgroup":"True","hovertemplate":"ETF=%{x}\u003cbr\u003eAvgDollarVolume=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["iShares MSCI","WisdomTree India Earnings Fund","iShares MSCI India Small-Cap","iShares India 50 ETF","Frnklin FTSE","Daily MSCI India","Columbia Consumer ETF","VanEck India Growth Leaders","Invesco India ETF","The India Internet"],"xaxis":"x","y":[176503662.94542065,31484040.16330165,6112630.365849418,4213373.465123696,4213325.872831541,2423966.33696202,1109812.020939538,965611.3660089889,817412.8370291323,262849.98400785157],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}]," ...

# %%
# -------------------------
# 6) PRINT EXPLANATIONS NEXT TO *YOUR* RESULTS
# -------------------------
print("===== WHAT YOUR NUMBERS MEAN (with your results) =====")
print(f"Benchmark: {BENCHMARK_TICKER} | Frequency: {'Weekly' if FREQ.startswith('W') else 'Daily'}")
print("\nKey concepts:")
print("- Tracking Error: how tightly ETF follows benchmark (annualized std of active returns).")
print("- Tracking Difference: average annual over/underperformance vs benchmark (annualized mean active return).")
print("- Information Ratio: active return per unit of tracking error (higher is better, but can be unstable).")
print("- Liquidity proxies: ADV (bigger=more liquid), Amihud (lower=more liquid), and % zero-volume days.\n")

for block in explanations:
    print(block)
# Out:
# ===== WHAT YOUR NUMBERS MEAN (with your results) =====
# Benchmark: ^NSEI | Frequency: Weekly
#
# Key concepts:
# - Tracking Error: how tightly ETF follows benchmark (annualized std of active returns).
# - Tracking Difference: average annual over/underperformance vs benchmark (annualized mean active return).
# - Information Ratio: active return per unit of tracking error (higher is better, but can be unstable).
# - Liquidity proxies: ADV (bigger=more liquid), Amihud (lower=more liquid), and % zero-volume days.
#
#
# [iShares MSCI] Tracking vs ^NSEI
# - Tracking Error (annualized): 9.15%
#   Meaning: typical yearly size of deviations from the benchmark. Lower = tracks closer.
#   Numbers: Under 0.5% is Excellent, 0.5-1.5% is Good/Acceptable and anything above 2% is very high and indicates significant performance deviation from the index.
# - Tracking Difference (annualized): -4.90%
#   Meaning: average annual over/underperformance vs benchmark. Positive = beat benchmark on average.
# - Information Ratio (IR): -0.54
#   Meaning: active return per unit of tracking error. Higher is better (if stable).
# - Beta vs benchmark: 1.01, R²: 0.76
#   Meaning: beta shows sensitivity to benchmark; R² shows how much ETF moves are explained by benchmark.
# - Alpha vs benchmark (annualized intercept): -5.01%
#   Meaning: average return not explained by benchmark exposure (not “true” CAPM alpha—benchmark-based).
#
#
# [iShares MSCI] Liquidity proxies
# - Average Dollar Volume (ADV): $176,503,663 per day
#   Meaning: bigger ADV usually = easier to trade with less price impact.
# - Amihud Illiquidity: 5.86e-11
#   Meaning: |return| per $ traded. Lower = more liquid (less price move per unit volume).
# - % Days zero/missing volume: 2.93%
#   Meaning: should be ~0% for liquid ETFs; higher can indicate stale/poor data or illiquidity.
#
#
# [Frnklin FTSE] Tracking vs ^NSEI
# - Tracking Error (annualized): 8.81%
#   Meaning: typical yearly size of deviations from the benchmark. Lower = tracks closer.
#   Numbers: Under 0.5% is Excellent, 0.5-1.5% is Good/Acceptable and anything above 2% is very high and indicates significant performance deviation from the index.
# - Tracking Difference (annualized): -4.07%
#   Meaning: average annual over/underperformance vs benchmark. Positive = beat benchmark on average.
# - Information Ratio (IR): -0.46
#   Meaning: active return per unit of tracking error. Higher is better (if stable).
# - Beta vs benchmark: 0.98, R²: 0.76
#   Meaning: beta shows sensitivity to benchmark; R² shows how much ETF moves are explained by benchmark.
# - Alpha vs benchmark (annualized intercept): -3.77%
#   Meaning: average return not explained by benchmark exposure (not “true” CAPM alpha—benchmark-based).
#
#
# [Frnklin FTSE] Liquidity proxies
# - Average Dollar Volume (ADV): $4,213,326 per day
#   Meaning: bigger ADV usually = easier to trade with less price impact.
# - Amihud Illiquidity: 1.77e-07
#   Meaning: |return| per $ traded. Lower = more liquid (less price move per unit volume).
# - % Days zero/missing volume: 3.94%
#   Meaning: should be ~0% for liquid ETFs; higher can indicate stale/poor data or illiquidity.
#
#
# [WisdomTree India Earnings Fund] Tracking vs ^NSEI
# - Tracking Error (annualized): 9.53%
#   Meaning: typical yearly size of deviations from the benchmark. Lower = tracks closer.
#   Numbers: Under 0.5% is Excellent, 0.5-1.5% is Good/Acceptable and anything above 2% is very high and indicates significant performance deviation from the index.
# - Tracking Difference (annualized): -3.25%
#   Meaning: average annual over/underperformance vs benchmark. Positive = beat benchmark on average.
# - Information Ratio (IR): -0.34
#   Meaning: active return per unit of tracking error. Higher is better (if stable).
# - Beta vs benchmark: 1.03, R²: 0.75
#   Meaning: beta shows sensitivity to benchmark; R² shows how much ETF moves are explained by benchmark.
# - Alpha vs benchmark (annualized intercept): -3.65%
#   Meaning: average return not explained by benchmark exposure (not “true” CAPM alpha—benchmark-based).
#
#
# [WisdomTree India Earnings Fund] Liquidity proxies
# - Average Dollar Volume (ADV): $31,484,040 per day
#   Meaning: bigger ADV usually = easier to trade with less price impact.
# - Amihud Illiquidity: 3.87e-10
#   Meaning: |return| per $ traded. Lower = more liquid (less price move per unit volume).
# - % Days zero/missing volume: 2.93%
#   Meaning: should be ~0% for liquid ETFs; higher can indicate stale/poor data or illiquidity.
#
#
# [iShares MSCI India Small-Cap] Tracking vs ^NSEI
# - Tracking Error (annualized): 13.86%
#   Meaning: typical yearly size of deviations from the benchmark. Lower = tracks closer.
#   Numbers: Under 0.5% is Excellent, 0.5-1.5% is Good/Acceptable and anything above 2% is very high and indicates significant performance deviation from the index.
# - Tracking Difference (annualized): -5.48%
#   Meaning: average annual over/underperformance vs benchmark. Positive = beat benchmark on average.
# - Information Ratio (IR): -0.40
#   Meaning: active return per unit of tracking error. Higher is better (if stable).
# - Beta vs benchmark: 1.02, R²: 0.58
#   Meaning: beta shows sensitivity to benchmark; R² shows how much ETF moves are explained by benchmark.
# - Alpha vs benchmark (annualized intercept): -5.75%
#   Meaning: average return not explained by benchmark exposure (not “true” CAPM alpha—benchmark-based).
#
#
# [iShares MSCI India Small-Cap] Liquidity proxies
# - Average Dollar Volume (ADV): $6,112,630 per day
#   Meaning: bigger ADV usually = easier to trade with less price impact.
# - Amihud Illiquidity: 5.95e-09
#   Meaning: |return| per $ traded. Lower = more liquid (less price move per unit volume).
# - % Days zero/missing volume: 2.93%
#   Meaning: should be ~0% for liquid ETFs; higher can indicate stale/poor data or illiquidity.
#
#
# [iShares India 50 ETF] Tracking vs ^NSEI
# - Tracking Error (annualized): 8.44%
#   Meaning: typical yearly size of deviations from the benchmark. Lower = tracks closer.
#   Numbers: Under 0.5% is Excellent, 0.5-1.5% is Good/Acceptable and anything above 2% is very high and indicates significant performance deviation from the index.
# - Tracking Difference (annualized): -5.02%
#   Meaning: average annual over/underperformance vs benchmark. Positive = beat benchmark on average.
# - Information Ratio (IR): -0.59
#   Meaning: active return per unit of tracking error. Higher is better (if stable).
# - Beta vs benchmark: 1.02, R²: 0.79
#   Meaning: beta shows sensitivity to benchmark; R² shows how much ETF moves are explained by benchmark.
# - Alpha vs benchmark (annualized intercept): -5.22%
#   Meaning: average return not explained by benchmark exposure (not “true” CAPM alpha—benchmark-based).
#
#
# [iShares India 50 ETF] Liquidity proxies
# - Average Dollar Volume (ADV): $4,213,373 per day
#   Meaning: bigger ADV usually = easier to trade with less price impact.
# - Amihud Illiquidity: 4.00e-09
#   Meaning: |return| per $ traded. Lower = more liquid (less price move per unit volume).
# - % Days zero/missing volume: 2.93%
#   Meaning: should be ~0% for liquid ETFs; higher can indicate stale/poor data or illiquidity.
#
#
# [Columbia Consumer ETF] Tracking vs ^NSEI
# - Tracking Error (annualized): 12.19%
#   Meaning: typical yearly size of deviations from the benchmark. Lower = tracks closer.
#   Numbers: Under 0.5% is Excellent, 0.5-1.5% is Good/Acceptable and anything above 2% is very high and indicates significant performance deviation from the index.
# - Tracking Difference (annualized): -4.75%
#   Meaning: average annual over/underperformance vs benchmark. Positive = beat benchmark on average.
# - Information Ratio (IR): -0.39
#   Meaning: active return per unit of tracking error. Higher is better (if stable).
# - Beta vs benchmark: 0.94, R²: 0.61
#   Meaning: beta shows sensitivity to benchmark; R² shows how much ETF moves are explained by benchmark.
# - Alpha vs benchmark (annualized intercept): -4.01%
#   Meaning: average return not explained by benchmark exposure (not “true” CAPM alpha—benchmark-based).
#
#
# [Columbia Consumer ETF] Liquidity proxies
# - Average Dollar Volume (ADV): $1,109,812 per day
#   Meaning: bigger ADV usually = easier to trade with less price impact.
# - Amihud Illiquidity: 4.08e-08
#   Meaning: |return| per $ traded. Lower = more liquid (less price move per unit volume).
# - % Days zero/missing volume: 2.93%
#   Meaning: should be ~0% for liquid ETFs; higher can indicate stale/poor data or illiquidity.
#
#
# [Invesco India ETF] Tracking vs ^NSEI
# - Tracking Error (annualized): 9.06%
#   Meaning: typical yearly size of deviations from the benchmark. Lower = tracks closer.
#   Numbers: Under 0.5% is Excellent, 0.5-1.5% is Good/Acceptable and anything above 2% is very high and indicates significant performance deviation from the index.
# - Tracking Difference (annualized): -4.33%
#   Meaning: average annual over/underperformance vs benchmark. Positive = beat benchmark on average.
# - Information Ratio (IR): -0.48
#   Meaning: active return per unit of tracking error. Higher is better (if stable).
# - Beta vs benchmark: 0.96, R²: 0.75
#   Meaning: beta shows sensitivity to benchmark; R² shows how much ETF moves are explained by benchmark.
# - Alpha vs benchmark (annualized intercept): -3.88%
#   Meaning: average return not explained by benchmark exposure (not “true” CAPM alpha—benchmark-based).
#
#
# [Invesco India ETF] Liquidity proxies
# - Average Dollar Volume (ADV): $817,413 per day
#   Meaning: bigger ADV usually = easier to trade with less price impact.
# - Amihud Illiquidity: 2.45e-08
#   Meaning: |return| per $ traded. Lower = more liquid (less price move per unit volume).
# - % Days zero/missing volume: 2.93%
#   Meaning: should be ~0% for liquid ETFs; higher can indicate stale/poor data or illiquidity.
#
#
# [The India Internet] Tracking vs ^NSEI
# - Tracking Error (annualized): 14.03%
#   Meaning: typical yearly size of deviations from the benchmark. Lower = tracks closer.
#   Numbers: Under 0.5% is Excellent, 0.5-1.5% is Good/Acceptable and anything above 2% is very high and indicates significant performance deviation from the index.
# - Tracking Difference (annualized): -10.30%
#   Meaning: average annual over/underperformance vs benchmark. Positive = beat benchmark on average.
# - Information Ratio (IR): -0.73
#   Meaning: active return per unit of tracking error. Higher is better (if stable).
# - Beta vs benchmark: 1.19, R²: 0.53
#   Meaning: beta shows sensitivity to benchmark; R² shows how much ETF moves are explained by benchmark.
# - Alpha vs benchmark (annualized intercept): -12.26%
#   Meaning: average return not explained by benchmark exposure (not “true” CAPM alpha—benchmark-based).
#
#
# [The India Internet] Liquidity proxies
# - Average Dollar Volume (ADV): $262,850 per day
#   Meaning: bigger ADV usually = easier to trade with less price impact.
# - Amihud Illiquidity: 8.54e-07
#   Meaning: |return| per $ traded. Lower = more liquid (less price move per unit volume).
# - % Days zero/missing volume: 3.67%
#   Meaning: should be ~0% for liquid ETFs; higher can indicate stale/poor data or illiquidity.
#
#
# [VanEck India Growth Leaders] Tracking vs ^NSEI
# - Tracking Error (annualized): 14.84%
#   Meaning: typical yearly size of deviations from the benchmark. Lower = tracks closer.
#   Numbers: Under 0.5% is Excellent, 0.5-1.5% is Good/Acceptable and anything above 2% is very high and indicates significant performance deviation from the index.
# - Tracking Difference (annualized): -14.06%
#   Meaning: average annual over/underperformance vs benchmark. Positive = beat benchmark on average.
# - Information Ratio (IR): -0.95
#   Meaning: active return per unit of tracking error. Higher is better (if stable).
# - Beta vs benchmark: 1.08, R²: 0.58
#   Meaning: beta shows sensitivity to benchmark; R² shows how much ETF moves are explained by benchmark.
# - Alpha vs benchmark (annualized intercept): -15.09%
#   Meaning: average return not explained by benchmark exposure (not “true” CAPM alpha—benchmark-based).
#
#
# [VanEck India Growth Leaders] Liquidity proxies
# - Average Dollar Volume (ADV): $965,611 per day
#   Meaning: bigger ADV usually = easier to trade with less price impact.
# - Amihud Illiquidity: 4.40e-08
#   Meaning: |return| per $ traded. Lower = more liquid (less price move per unit volume).
# - % Days zero/missing volume: 2.93%
#   Meaning: should be ~0% for liquid ETFs; higher can indicate stale/poor data or illiquidity.
#
#
# [Daily MSCI India] Tracking vs ^NSEI
# - Tracking Error (annualized): 36.53%
#   Meaning: typical yearly size of deviations from the benchmark. Lower = tracks closer.
#   Numbers: Under 0.5% is Excellent, 0.5-1.5% is Good/Acceptable and anything above 2% is very high and indicates significant performance deviation from the index.
# - Tracking Difference (annualized): -6.52%
#   Meaning: average annual over/underperformance vs benchmark. Positive = beat benchmark on average.
# - Information Ratio (IR): -0.18
#   Meaning: active return per unit of tracking error. Higher is better (if stable).
# - Beta vs benchmark: 2.63, R²: 0.73
#   Meaning: beta shows sensitivity to benchmark; R² shows how much ETF moves are explained by benchmark.
# - Alpha vs benchmark (annualized intercept): -26.60%
#   Meaning: average return not explained by benchmark exposure (not “true” CAPM alpha—benchmark-based).
#
#
# [Daily MSCI India] Liquidity proxies
# - Average Dollar Volume (ADV): $2,423,966 per day
#   Meaning: bigger ADV usually = easier to trade with less price impact.
# - Amihud Illiquidity: 1.22e-08
#   Meaning: |return| per $ traded. Lower = more liquid (less price move per unit volume).
# - % Days zero/missing volume: 2.93%
#   Meaning: should be ~0% for liquid ETFs; higher can indicate stale/poor data or illiquidity.
